# %% [markdown]
# <a href="https://colab.research.google.com/github/akshay635/SportsAnalytics/blob/main/Suryakumar%20Yadav%20IPL%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Importing the useful libraries for data analysis

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Fetching data from csv files using pandas built-in function pd.read_csv

# %%
ipl_ball_data = pd.read_csv('/IPL_Ball_by_Ball_2008_2022.csv')
ipl_match_data = pd.read_csv('/IPL_Matches_2008_2022.csv')

# %% [markdown]
# Displaying the top 5 data from dataset

# %%
ipl_ball_data.head(5)
# Out:
#         ID  innings  overs  ballnumber       batter          bowler  \
# 0  1312200        1      0           1  YBK Jaiswal  Mohammed Shami
# 1  1312200        1      0           2  YBK Jaiswal  Mohammed Shami
# 2  1312200        1      0           3   JC Buttler  Mohammed Shami
# 3  1312200        1      0           4  YBK Jaiswal  Mohammed Shami
# 4  1312200        1      0           5  YBK Jaiswal  Mohammed Shami
#
#    non-striker extra_type  batsman_run  extras_run  total_run  non_boundary  \
# 0   JC Buttler        NaN          0.0         0.0        0.0           0.0
# 1   JC Buttler    legbyes          0.0         1.0        1.0           0.0
# 2  YBK Jaiswal        NaN          1.0         0.0        1.0           0.0
# 3   JC Buttler        NaN          0.0         0.0        0.0           0.0
# 4   JC Buttler        NaN          0.0         0.0        0.0           0.0
#
#    isWicketDelivery player_out kind fielders_involved       BattingTeam
# 0               0.0        NaN  NaN               NaN  Rajasthan Royals
# 1               0.0        NaN  NaN               NaN  Rajasthan Royals
# 2               0.0        NaN  NaN               NaN  Rajasthan Royals
# 3               0.0        NaN  NaN               NaN  Rajasthan Royals
# 4               0.0        NaN  NaN               NaN  Rajasthan Royals

# %% [markdown]
# Collecting data of Cricketer Suryakumar Yadav by filtering the data

# %%
sky_data = ipl_ball_data[ipl_ball_data['batter'] == 'SA Yadav']

# %%
sky_data
# Out:
#             ID  innings  overs  ballnumber    batter       bowler  \
# 5559   1304097        1      7           4  SA Yadav  Rashid Khan
# 5560   1304097        1      7           5  SA Yadav  Rashid Khan
# 5563   1304097        1      8           2  SA Yadav    R Tewatia
# 5566   1304097        1      8           5  SA Yadav    R Tewatia
# 5569   1304097        1      9           2  SA Yadav  LH Ferguson
# ...        ...      ...    ...         ...       ...          ...
# 46714  1216492        1      9           7  SA Yadav    PP Chawla
# 46716  1216492        1     10           2  SA Yadav    DL Chahar
# 46717  1216492        1     10           3  SA Yadav    DL Chahar
# 46720  1216492        1     10           6  SA Yadav    DL Chahar
# 46721  1216492        1     10           7  SA Yadav    DL Chahar
#
#         non-striker extra_type  batsman_run  extras_run  total_run  \
# 5559   Ishan Kishan        NaN          0.0         0.0        0.0
# 5560   Ishan Kishan        NaN          1.0         0.0        1.0
# 5563   Ishan Kishan        NaN          1.0         0.0        1.0
# 5566   Ishan Kishan        NaN          1.0         0.0        1.0
# 5569   Ishan Kishan        NaN          6.0         0.0        6.0
# ...             ...        ...          ...         ...        ...
# 46714     SS Tiwary        NaN          0.0         0.0        0.0
# 46716     SS Tiwary        NaN          0.0         0.0        0.0
# 46717     SS Tiwary        NaN          1.0         0.0        1.0
# 46720     SS Tiwary      wides          0.0         1.0        1.0
# 46721     SS Tiwary        NaN          0.0         0.0        0.0
#
#        non_boundary  isWicketDelivery player_out    kind fielders_involved  \
# 5559            0.0               0.0        NaN     NaN               NaN
# 5560            0.0               0.0        NaN     NaN               NaN
# 5563            0.0               0.0        NaN     NaN               NaN
# 5566            0.0               0.0        NaN     NaN               NaN
# 5569            0.0               0.0        NaN     NaN               NaN
# ...             ...               ...        ...     ...               ...
# 46714           0.0               0.0        NaN     NaN               NaN
# 46716           0.0               0.0        NaN     NaN               NaN
# 46717           0.0               0.0        NaN     NaN               NaN
# 46720           0.0               0.0        NaN     NaN               NaN
# 46721           0.0               1.0   SA Yadav  caught         SM Curran
#
#           BattingTeam
# 5559   Mumbai Indians
# 5560   Mumbai Indians
# 5563   Mumbai Indians
# 5566   Mumbai Indians
# 5569   Mumbai Indians
# ...               ...
# 46714  Mumbai Indians
# 46716  Mumbai Indians
# 46717  Mumbai Indians
# 46720  Mumbai Indians
# 46721  Mumbai Indians
#
# [776 rows x 17 columns]

# %% [markdown]
#           Suryakumar Yadav's ball to ball data in IPL from 2008 to 2022

# %%
sky_data['ballnumber'].value_counts()
# Out:
# 6    133
# 4    131
# 3    129
# 2    122
# 1    122
# 5    116
# 7     20
# 8      3
# Name: ballnumber, dtype: int64

# %% [markdown]
# Total Number of balls played by Suryakumar Yadav

# %%
sky_data['ballnumber'].count()
# Out:
# 776

# %% [markdown]
# Total runs scored by Suryakumar Yadav

# %%
sky_data['batsman_run'].sum()
# Out:
# 1100.0

# %% [markdown]
# Formula to calculate average strike rate of a batsman

# %%
strike_rate = (sky_data['batsman_run'].sum() / sky_data['ballnumber'].count())*100

# %% [markdown]
# Average Strike rate of Suryakumar Yadav

# %%
round(strike_rate)
# Out:
# 142

# %% [markdown]
# 4s-124
#
# 6s-37
#
# 2s-38
#
# 3s-3
#
# 1s-297
#
# dots-277

# %%
sky_data['batsman_run'].value_counts()
# Out:
# 1.0    297
# 0.0    277
# 4.0    124
# 2.0     38
# 6.0     37
# 3.0      3
# Name: batsman_run, dtype: int64

# %% [markdown]
# 31 times he has got dismissed in ipl

# %%
sky_data['isWicketDelivery'].value_counts()
# Out:
# 0.0    745
# 1.0     31
# Name: isWicketDelivery, dtype: int64

# %%
d1 = pd.DataFrame(sky_data.groupby(['ID'])['ballnumber'].count())

# %%
d2 = pd.DataFrame(sky_data.groupby(['ID'])['batsman_run'].sum())

# %%
d1
# Out:
#          ballnumber
# ID
# 1216492          18
# 1216495          29
# 1216499          44
# 1216503           7
# 1216508          28
# 1216511          49
# 1216517           4
# 1216526          10
# 1216529          33
# 1216535          11
# 1216538          18
# 1216541          29
# 1216547           2
# 1237177          38
# 1237181          20
# 1254058          23
# 1254062          38
# 1254066           6
# 1254070          15
# 1254074          28
# 1254081          10
# 1254084           3
# 1254088          41
# 1254093           9
# 1254096          10
# 1254099           1
# 1254104           7
# 1254108           9
# 1254112          26
# 1304060          36
# 1304064          37
# 1304069          30
# 1304072          29
# 1304079          21
# 1304083           7
# 1304090          39
# 1304097          11

# %%
d2
# Out:
#          batsman_run
# ID
# 1216492         17.0
# 1216495         36.0
# 1216499         79.0
# 1216503         10.0
# 1216508         47.0
# 1216511         79.0
# 1216517          0.0
# 1216526         10.0
# 1216529         53.0
# 1216535         12.0
# 1216538         27.0
# 1216541         40.0
# 1216547          0.0
# 1237177         51.0
# 1237181         19.0
# 1254058         31.0
# 1254062         56.0
# 1254066         10.0
# 1254070         24.0
# 1254074         33.0
# 1254081         16.0
# 1254084          3.0
# 1254088         82.0
# 1254093         13.0
# 1254096          5.0
# 1254099          0.0
# 1254104          3.0
# 1254108          8.0
# 1254112         33.0
# 1304060         52.0
# 1304064         68.0
# 1304069         43.0
# 1304072         37.0
# 1304079         32.0
# 1304083          7.0
# 1304090         51.0
# 1304097         13.0

# %%
d3 = pd.merge(d1, d2, how='inner', on = 'ID')

# %% [markdown]
# This d3 dataframe shows match-by-match data of Suryakumar Yadav

# %%
d3
# Out:
#          ballnumber  batsman_run
# ID
# 1216492          18         17.0
# 1216495          29         36.0
# 1216499          44         79.0
# 1216503           7         10.0
# 1216508          28         47.0
# 1216511          49         79.0
# 1216517           4          0.0
# 1216526          10         10.0
# 1216529          33         53.0
# 1216535          11         12.0
# 1216538          18         27.0
# 1216541          29         40.0
# 1216547           2          0.0
# 1237177          38         51.0
# 1237181          20         19.0
# 1254058          23         31.0
# 1254062          38         56.0
# 1254066           6         10.0
# 1254070          15         24.0
# 1254074          28         33.0
# 1254081          10         16.0
# 1254084           3          3.0
# 1254088          41         82.0
# 1254093           9         13.0
# 1254096          10          5.0
# 1254099           1          0.0
# 1254104           7          3.0
# 1254108           9          8.0
# 1254112          26         33.0
# 1304060          36         52.0
# 1304064          37         68.0
# 1304069          30         43.0
# 1304072          29         37.0
# 1304079          21         32.0
# 1304083           7          7.0
# 1304090          39         51.0
# 1304097          11         13.0

# %% [markdown]
# Adding Strike rate column

# %%
d3['strike_rate'] = (d3['batsman_run']/d3['ballnumber'])*100

# %% [markdown]
# This is the final dataframe showing runs scored by SA Yadav in each innings along with balls faced and strike rate

# %%
d3
# Out:
#          ballnumber  batsman_run  strike_rate
# ID
# 1216492          18         17.0    94.444444
# 1216495          29         36.0   124.137931
# 1216499          44         79.0   179.545455
# 1216503           7         10.0   142.857143
# 1216508          28         47.0   167.857143
# 1216511          49         79.0   161.224490
# 1216517           4          0.0     0.000000
# 1216526          10         10.0   100.000000
# 1216529          33         53.0   160.606061
# 1216535          11         12.0   109.090909
# 1216538          18         27.0   150.000000
# 1216541          29         40.0   137.931034
# 1216547           2          0.0     0.000000
# 1237177          38         51.0   134.210526
# 1237181          20         19.0    95.000000
# 1254058          23         31.0   134.782609
# 1254062          38         56.0   147.368421
# 1254066           6         10.0   166.666667
# 1254070          15         24.0   160.000000
# 1254074          28         33.0   117.857143
# 1254081          10         16.0   160.000000
# 1254084           3          3.0   100.000000
# 1254088          41         82.0   200.000000
# 1254093           9         13.0   144.444444
# 1254096          10          5.0    50.000000
# 1254099           1          0.0     0.000000
# 1254104           7          3.0    42.857143
# 1254108           9          8.0    88.888889
# 1254112          26         33.0   126.923077
# 1304060          36         52.0   144.444444
# 1304064          37         68.0   183.783784
# 1304069          30         43.0   143.333333
# 1304072          29         37.0   127.586207
# 1304079          21         32.0   152.380952
# 1304083           7          7.0   100.000000
# 1304090          39         51.0   130.769231
# 1304097          11         13.0   118.181818

# %%
len(d3)
# Out:
# 37

# %% [markdown]
# Number of innings played by Suryakumar Yadav

# %%
d3['batsman_run'].sum()
# Out:
# 1100.0

# %% [markdown]
# Formula for calculating batting average of a batsman

# %%
average = d3['batsman_run'].sum()/len(d3)

# %%
round(average)
# Out:
# 30

# %% [markdown]
# Batting Average of Suryakumar Yadav in IPL

# %%
plt.bar(d3['ballnumber'], d3['strike_rate'], width = 0.75)
# Out:
# <BarContainer object of 37 artists>

# %%
plt.bar(d3['ballnumber'], d3['batsman_run'], width = 0.8)
# Out:
# <BarContainer object of 37 artists>
